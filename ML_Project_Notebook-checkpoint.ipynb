# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
"""Capacited Vehicles Routing Problem (CVRP) with distance and time constraints."""

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# %% [markdown]
# Function create_data_model: model instance

# %%
def create_data_model(distance_matrix_WK: list, time_matrix_WK:list, vehicle_cap: list, demands: list, 
                      num_vehicles:int, max_distance:int, max_time: int, wait_times:list):

    '''
    distance_matrix_WK 
    num_vehicles: number of available vehicles
    max_distance: maximum distance per route (kms)
    max_time: maximum time per route (hours)
    wait_time: average waiting time at each node
    vehicle_cap: vehicle capacities

    '''
    data = {}
    data["distance_matrix"] = distance_matrix_WK
    data['time_matrix'] = time_matrix_WK
    data["demands"] = demands
    
    data["num_vehicles"] = num_vehicles
    data["vehicle_capacities"] = vehicle_cap
    data["depot"] = 0
    data['maximum_distance']=max_distance
    data['maximum_time'] = max_time
    data['waiting_times'] =wait_times
    return data

# %% [markdown]
# Function print_solution: data

# %%
def print_solution(data, manager, routing, solution):
    """Prints solution on console."""
    global avg_speed
    print(f"Objective: {solution.ObjectiveValue()}")
    total_distance=0
    total_time = 0
    total_load = 0
    for vehicle_id in range(data["num_vehicles"]):
        index = routing.Start(vehicle_id)
        plan_output = f"Route for vehicle {vehicle_id}:\n"
        route_time = 0
        route_load = 0
        route_distance =0
        while not routing.IsEnd(index):
            node_index = manager.IndexToNode(index)
            route_load += data["demands"][node_index]
            plan_output += f" {node_index} Load({route_load}) -> "
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_time += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id)
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id
            )*avg_speed
        plan_output += f" {manager.IndexToNode(index)} Load({route_load})\n"
        #plan_output += f"Distance of the route: {route_distance}m\n"
        plan_output += f"Time of the route: {route_time}\n"
        plan_output += f"Load of the route: {route_load}\n"
        print(plan_output)
        total_distance += route_distance
        total_time += route_time
        total_load += route_load
    total_time = round(total_time/60,1)
    print(f"Total time of all routes: {total_time}")
    #print(f"Total distance of all routes: {total_distance}m")
    print(f"Total load of all routes: {total_load}")

# %%
def main(data: dict, first_solution: str, algorithm: str):
    """Solve the CVRP problem."""
    # Instantiate the data problem.
    #data = create_data_model()
    
    #print(sum(data['demands']))
    #print(data["vehicle_capacities"])

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(
        len(data["distance_matrix"]), data["num_vehicles"], data["depot"]
    )

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)

    # Add Capacity constraint.
    #Create demand allback 
    def demand_callback(from_index):
        """Returns the demand of the node."""
        # Convert from routing variable Index to demands NodeIndex.
        from_node = manager.IndexToNode(from_index)
        return data["demands"][from_node]

    #register callback
    demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
    
    #Adds constraint
    routing.AddDimensionWithVehicleCapacity(
        demand_callback_index,
        0,  # null capacity slack
        data["vehicle_capacities"],  # vehicle maximum capacities
        True,  # start cumul to zero
        "Capacity",
    )

    #add Distance constraint
    # Create and register a distance callback.
    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data["distance_matrix"][from_node][to_node]
    
       # Adds the maximum distance constraint.

    dimension_name = "Distance"
    distance_callback_index = routing.RegisterTransitCallback(distance_callback)

    routing.AddDimension(
        distance_callback_index,
        0,  # no slack
        data['maximum_distance'],  # vehicle maximum travel distance
        True,  # start cumul to zero
        dimension_name,
    )
    
    #max time constraint
    dimension_name = "Time"
    def time_callback(from_index, to_index):
        """Returns the time between the two nodes + the waiting time."""
        # Convert from routing variable Index to time matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        
        return data["time_matrix"][from_node][to_node] + data['waiting_times'][to_node]
    
    # Adds the maximum time constraint.
   
    time_callback_index = routing.RegisterTransitCallback(time_callback)

    routing.AddDimension(
        time_callback_index,
        0,  # no slack
        data['maximum_time'],  # vehicle maximum time per route
        True,  # start cumul to zero
        dimension_name,
    )

    #distance_dimension = routing.GetDimensionOrDie('Distance')
    #distance_dimension.SetGlobalSpanCostCoefficient(1000)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(time_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    if first_solution == 'AUTOMATC':
        search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.AUTOMATIC
        )
    elif first_solution == 'PATH_CHEAPEST_ARC':
        search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
        )
    elif first_solution == 'PATH_MOST_CONSTRAINED_ARC':
        search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_MOST_CONSTRAINED_ARC
        ) 
    elif search_parameters.first_solution_strategy == 'SAVINGS':
        search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.SAVINGS
        )
    elif search_parameters.first_solution_strategy == 'BEST_INSERTION':
        search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.BEST_INSERTION
        )
    elif first_solution == 'FIRST_UNBOUND_MIN_VALUE':
        search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.FIRST_UNBOUND_MIN_VALUE
        )
    else:
        search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
        )
 
    #Sets the algorithm
    if algorithm== 'TABU_SEARCH':
        search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.TABU_SEARCH
    elif algorithm== 'GUIDED_LOCAL_SEARCH':
        search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
    elif algorithm== 'AUTOMATIC':
        search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.AUTOMATIC
    elif algorithm== 'SIMULATED_ANNEALING':
        search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.SIMULATED_ANNEALING
    elif algorithm== 'GREEDY_DESCENT':
        search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.GREEDY_DESCENT
    elif algorithm== 'GENERIC_TABU_SEARCH':
        search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.GENERIC_TABU_SEARCH
    else:
        search_parameters.local_search_metaheuristic = routing_enums_pb2.LocalSearchMetaheuristic.AUTOMATIC

    search_parameters.time_limit.FromSeconds(5)

    # Solve the problem.
    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)
    else:
        print('No solution found')

# %%
def assign_weeks_equal_nodes(df):

    '''
    Attempts to balance nodes across weeks
    '''
    
    df['Week_1']=0
    df['Week_2']=0
    df['Week_3']=0
    df['Week_4']=0
    for i in range(0,df.shape[0]):
        
        if df.iloc[i,3]== 'Weekly' or df.iloc[i,3]=='No':
            df.iloc[i,7] = 1
            df.iloc[i,8] = 1
            df.iloc[i,9] = 1
            df.iloc[i,10] = 1
        elif df.iloc[i,3]== 'Biweekly':
            #print(i, df.at[i,'Organization'])
            if (i % 2 )==0:
                df.iloc[i,7] = 1
                df.iloc[i,9] = 1
            else:
                df.iloc[i,8] = 1
                df.iloc[i,10] = 1
        elif df.iloc[i,3] == 'Monthly':
            if(i % 4 )==1:
                df.iloc[i,7] = 1
            elif(i % 4 )==2:
                df.iloc[i,8] = 1
            elif(i % 4 )==3:
                df.iloc[i,9] = 1
            else:
                df.iloc[i,10] = 1
                
    print('Nodes served by week')
    for t in range(4):
        print(f'Week_{t+1}', end='\t')
    print()
    for t in range(4):
        print(df[f'Week_{t+1}'].sum(), end='\t')
    print()
    return df

# %%
def assign_weeks_random(df):

    '''
    Randomly assigns nodes to weeks
    '''

    df['Week_1']=0
    df['Week_2']=0
    df['Week_3']=0
    df['Week_4']=0
    rnd_no=0
    for i in range(0,df.shape[0]):
        #print(df.at[i,'Organization'])
        if df.iloc[i,3]== 'Weekly' or df.iloc[i,3]=='No':
            df.iloc[i,7] = 1
            df.iloc[i,8] = 1
            df.iloc[i,9] = 1
            df.iloc[i,10] = 1
        elif df.iloc[i,3]== 'Biweekly':
            rnd_no = np.random.randint(0,2)
            if rnd_no ==0:
                df.iloc[i,7] = 1
                df.iloc[i,9] = 1
            else:
                df.iloc[i,8] = 1
                df.iloc[i,10] = 1
        elif df.iloc[i,3] == 'Monthly':
            rnd_no = np.random.randint(0,4)
            if(rnd_no ==1):
                df.iloc[i,7] = 1 #Week 1
            elif(rnd_no ==2):
                df.iloc[i,8] = 1  #Week 2
            elif(rnd_no ==3):
                df.iloc[i,9] = 1  #Week 3
            else:
                df.iloc[i,10] = 1  #Week 4

    print('Nodes served by week')
    for t in range(4):
        print(f'Week_{t+1}', end='\t')
    print()
    for t in range(4):
        print(df[f'Week_{t+1}'].sum(), end='\t')
    print()
    return df

# %%
def assign_weeks_equal_load(df):

    '''
    Attempts to balance loads across weeks
    '''

    df =df.sort_values(by='Demand', ascending=False)
    weekly_loads = [0]*4
    
    df['Week_1']=0
    df['Week_2']=0
    df['Week_3']=0
    df['Week_4']=0
    df = df.sort_values(by='Demand', ascending=False)

    for i in range(0,df.shape[0]):

        min_load = min(weekly_loads)
        min_index = weekly_loads.index(min_load) 

        
        if df.iloc[i,3]== 'Weekly' or df.iloc[i,3]=='No':

            df.iloc[i,7] = 1
            df.iloc[i,8] = 1
            df.iloc[i,9] = 1
            df.iloc[i,10] = 1
        
            for j in range(4): #weeks
                weekly_loads[j] = weekly_loads[j] + df.iloc[i,2]

        elif df.iloc[i,3]== 'Biweekly':

            if (min_index ==0 or min_index==2):
                df.iloc[i,7] = 1
                df.iloc[i,9] = 1
                weekly_loads[0] = weekly_loads[0] + df.iloc[i,2]
                weekly_loads[2] = weekly_loads[2] + df.iloc[i,2]
            else: 
                df.iloc[i,8] = 1
                df.iloc[i,10] = 1
                weekly_loads[1] = weekly_loads[1] + df.iloc[i,2]
                weekly_loads[3] = weekly_loads[3] + df.iloc[i,2]
            
        elif df.iloc[i,3]== 'Monthly':

            if min_index == 1:
                df.iloc[i,7] = 1
            elif min_index == 2:
                df.iloc[i,8] = 1
            elif min_index == 3:
                df.iloc[i,9] = 1
            elif min_index == 0:
                df.iloc[i,10] = 1
            weekly_loads[min_index] = weekly_loads[min_index] + df.iloc[i,2]
 
    df = df.sort_index()

    print('Nodes served by week')
    for t in range(4):
        print(f'Week_{t+1}', end='\t')
    print()
    for t in range(4):
        print(df[f'Week_{t+1}'].sum(), end='\t')
    print()
    
    return df

# %%
def assign_weeks_Luz(df):
    '''
    Assigns all monthly nodes to week 1, all biweekly to weeks 2 and 4
    '''

    df['Week_1']=0
    df['Week_2']=0
    df['Week_3']=0
    df['Week_4']=0
    for i in range(0,df.shape[0]):
        if df.iloc[i,3]== 'Weekly' or df.iloc[i,3]=='No':
            df.iloc[i,7] = 1
            df.iloc[i,8] = 1
            df.iloc[i,9] = 1
            df.iloc[i,10] = 1
        elif df.iloc[i,3]== 'Biweekly':
            df.iloc[i,8] = 1
            df.iloc[i,10] = 1
        elif df.iloc[i,3]== 'Monthly':
            df.iloc[i,7] = 1
            
    print('Nodes served by week')
    for t in range(4):
        print(f'Week_{t+1}', end='\t')
    print()
    for t in range(4):
        print(df[f'Week_{t+1}'].sum(), end='\t')
    print()
    return df

# %%
def init_schedules (region: str, assignment: str): 
    '''
    region: 'N', 'SE', 'SW', 'C'
    assignment 'EQUAL_NODES', 'EQUAL_LOADS', 'RANDOM'
    '''
    global df

    region_dict = {'N': 'North', 'SE': 'Southeast', 'SW': 'Southwest', 'C': 'Central'}
    filter =  (df['Cluster']==region_dict[region]) | (df['Cluster']=='No') #filters by region. Includes the BAB

    df_region = df[filter].copy()
    df_region.reset_index(inplace=True)
    n_weeks = 4

    df_region.drop('index', axis=1, inplace=True)

    if assignment == 'EQUAL_NODES':
        df_region = assign_weeks_equal_nodes(df_region)
    elif assignment == 'EQUAL_LOADS':
        df_region = assign_weeks_equal_load(df_region)
    elif assignment == 'LUZ':
        df_region = assign_weeks_Luz(df_region)
    else:
        df_region = assign_weeks_random(df_region)

    #df_region.head(10)
    return df_region

# %% [markdown]
# First solution <br>
# AUTOMATIC	Lets the solver detect which strategy to use according to the model being solved. <br>
# PATH_CHEAPEST_ARC	Starting from a route "start" node, connect it to the node which produces the cheapest route segment, then extend the route by iterating on the last node added to the route. <br>
# PATH_MOST_CONSTRAINED_ARC	Similar to PATH_CHEAPEST_ARC, but arcs are evaluated with a comparison-based selector which will favor the most constrained arc first. To assign a selector to the routing model, use the method ArcIsMoreConstrainedThanArc().
# SAVINGS	Savings algorithm (Clarke & Wright). Reference Clarke, G. & Wright, J.W. "Scheduling of Vehicles from a Central Depot to a Number of Delivery Points" , Operations Research, Vol. 12, 1964, pp. 568-581. <br>
# BEST_INSERTION	Iteratively build a solution by inserting the cheapest node at its cheapest position; the cost of insertion is based on the global cost function of the routing model. As of 2/2012, only works on models with optional nodes (with finite penalty costs).<br>
# FIRST_UNBOUND_MIN_VALUE	Select the first node with an unbound successor and connect it to the first available node. This is equivalent to the CHOOSE_FIRST_UNBOUND strategy combined with ASSIGN_MIN_VALUE (cf. constraint_solver.h). <br>
#
# Algorithm <br>
# AUTOMATIC	Lets the solver select the metaheuristic.<br>
# GREEDY_DESCENT	Accepts improving (cost-reducing) local search neighbors until a local minimum is reached. <br>
# GUIDED_LOCAL_SEARCH	Uses guided local search to escape local minima. (cf. Guided Local Search) this is generally the most efficient
# metaheuristic for vehicle routing.<br>
# SIMULATED_ANNEALING	Uses simulated annealing to escape local minima (cf. Simulated Annealing).<br>
# TABU_SEARCH	Uses tabu search to escape local minima (cf. Tabu Search).<br>
# GENERIC_TABU_SEARCH	Uses tabu search on the objective value of solution to escape local minima.<br><br>
#
# Assigment <br>
# EQUAL_LOADS: balances the loads in each week. <br>
# EQUAL_NODES: balances the number of nodes served in each week. <br>
# RANDOM:randomly assigns nodes to weeks. <br>
# LUZ: Original of Luz Helena

# %%
if __name__ == "__main__":
    np.random.seed(1234)
    algorithm = 'GREEDY_DESCENT'
    assignment =    'RANDOM'
    first_solution = 'BEST_INSERTION'
    distance_matrices_names = ['distance_matrix_N.xlsx', 'distance_matrix_SE.xlsx', 'distance_matrix_SW.xlsx', 'distance_matrix_C.xlsx']
    clusters = ['N', 'SE', 'SW', 'C']
    cluster_names ={ 'N': 'North', 'SE': 'South East', 'SW': 'South West', 'C': 'Central',}
    avg_speed = 25*1000/60 #m/min 25 Km / hr = 416 m / min
    num_vehicles = 35
    truck_capacity = 3000 #Kgs
    max_distance = 80000 #mts
    max_route_time = 600 #minutes max
    wait_time = 60 # minutes 

    #Reads the database from excel
    df = pd.read_excel('Fundaciones_total.xlsx')


    n_weeks=4 #number of weeks per month
    for t in range(4):
        column_name = f'Week_{t+1}'
        df.loc[:,column_name] = 0
        df.head()
    
    vehicle_capacities = [truck_capacity]*num_vehicles 
    num_clusters = 4
    print('Assignment:', assignment, 'First Solution:', first_solution, 'VRP algorithm:', algorithm)
    
    for i in range(num_clusters):

        #Reads the distance matrix
        df_distances = pd.read_excel(distance_matrices_names[i],header=None)
        distance_matrix = np.round(df_distances.to_numpy())    
        time_matrix = np.round(distance_matrix/avg_speed).astype(int)
    
        print(cluster_names[clusters[i]])

        
        df_region = init_schedules(clusters[i], assignment)
    
       
        for t in range(n_weeks):
            
            print('Week', t+1)
            week = f'Week_{t+1}'

         
            df_week= df_region[df_region[week]==1].copy()
            
            index_list = df_week.index.tolist()
            demands = df_week['Demand'].tolist()
            wait_times = [60]* len(demands) 
            wait_times[0]=0 
            
            
            distance_matrix_WK = distance_matrix[index_list][:,index_list].tolist()
            time_matrix_WK = time_matrix[index_list][:,index_list].tolist()
            
            
            data = create_data_model(distance_matrix_WK, time_matrix_WK, vehicle_capacities, demands, 
                            num_vehicles, max_distance, max_route_time, wait_times)
            
            
            main(data, first_solution, algorithm)
        
        print('\n')
# Out:
# Assignment: RANDOM First Solution: BEST_INSERTION VRP algorithm: GREEDY_DESCENT
# North
# Nodes served by week
# Week_1	Week_2	Week_3	Week_4
# 49	57	49	58
# Week 1
# Objective: 3764
# Route for vehicle 0:
#  0 Load(0) ->  25 Load(293) ->  27 Load(670) ->  19 Load(1346) ->  18 Load(1703) ->  34 Load(1993) ->  26 Load(2743) ->  28 Load(2981) ->  0 Load(2981)
# Time of the route: 539
# Load of the route: 2981
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 22:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 23:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 24:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 25:
#  0 Load(0) ->  11 Load(51) ->  40 Load(230) ->  30 Load(469) ->  8 Load(760) ->  21 Load(2125) ->  36 Load(2239) ->  29 Load(2788) ->  0 Load(2788)
# Time of the route: 528
# Load of the route: 2788
#
# Route for vehicle 26:
#  0 Load(0) ->  43 Load(526) ->  15 Load(754) ->  32 Load(1889) ->  12 Load(2324) ->  45 Load(2997) ->  0 Load(2997)
# Time of the route: 421
# Load of the route: 2997
#
# Route for vehicle 27:
#  0 Load(0) ->  41 Load(1134) ->  39 Load(2242) ->  7 Load(2513) ->  0 Load(2513)
# Time of the route: 250
# Load of the route: 2513
#
# Route for vehicle 28:
#  0 Load(0) ->  13 Load(1147) ->  22 Load(2439) ->  46 Load(2622) ->  0 Load(2622)
# Time of the route: 259
# Load of the route: 2622
#
# Route for vehicle 29:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 30:
#  0 Load(0) ->  33 Load(3000) ->  0 Load(3000)
# Time of the route: 119
# Load of the route: 3000
#
# Route for vehicle 31:
#  0 Load(0) ->  4 Load(102) ->  1 Load(789) ->  24 Load(1449) ->  2 Load(1947) ->  3 Load(2494) ->  20 Load(2713) ->  6 Load(2898) ->  0 Load(2898)
# Time of the route: 529
# Load of the route: 2898
#
# Route for vehicle 32:
#  0 Load(0) ->  35 Load(153) ->  5 Load(614) ->  37 Load(1184) ->  38 Load(1576) ->  9 Load(2104) ->  10 Load(2836) ->  0 Load(2836)
# Time of the route: 417
# Load of the route: 2836
#
# Route for vehicle 33:
#  0 Load(0) ->  16 Load(909) ->  48 Load(1336) ->  17 Load(2016) ->  47 Load(2310) ->  23 Load(2611) ->  14 Load(2852) ->  0 Load(2852)
# Time of the route: 467
# Load of the route: 2852
#
# Route for vehicle 34:
#  0 Load(0) ->  42 Load(834) ->  31 Load(1889) ->  44 Load(2643) ->  0 Load(2643)
# Time of the route: 235
# Load of the route: 2643
#
# Total time of all routes: 62.7
# Total load of all routes: 28130
# Week 2
# Objective: 4331
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 22:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 23:
#  0 Load(0) ->  6 Load(185) ->  41 Load(363) ->  40 Load(671) ->  28 Load(1245) ->  3 Load(1792) ->  35 Load(2658) ->  18 Load(2936) ->  0 Load(2936)
# Time of the route: 525
# Load of the route: 2936
#
# Route for vehicle 24:
#  0 Load(0) ->  46 Load(237) ->  8 Load(528) ->  43 Load(819) ->  15 Load(1047) ->  48 Load(1219) ->  29 Load(2730) ->  0 Load(2730)
# Time of the route: 488
# Load of the route: 2730
#
# Route for vehicle 25:
#  0 Load(0) ->  4 Load(102) ->  1 Load(789) ->  26 Load(1065) ->  2 Load(1563) ->  27 Load(2127) ->  36 Load(2417) ->  5 Load(2878) ->  0 Load(2878)
# Time of the route: 522
# Load of the route: 2878
#
# Route for vehicle 26:
#  0 Load(0) ->  54 Load(429) ->  14 Load(670) ->  12 Load(1105) ->  52 Load(2064) ->  44 Load(2926) ->  0 Load(2926)
# Time of the route: 394
# Load of the route: 2926
#
# Route for vehicle 27:
#  0 Load(0) ->  39 Load(1512) ->  19 Load(2836) ->  0 Load(2836)
# Time of the route: 198
# Load of the route: 2836
#
# Route for vehicle 28:
#  0 Load(0) ->  33 Load(572) ->  32 Load(1344) ->  13 Load(2491) ->  51 Load(2735) ->  0 Load(2735)
# Time of the route: 314
# Load of the route: 2735
#
# Route for vehicle 29:
#  0 Load(0) ->  16 Load(909) ->  17 Load(1589) ->  25 Load(2891) ->  0 Load(2891)
# Time of the route: 270
# Load of the route: 2891
#
# Route for vehicle 30:
#  0 Load(0) ->  11 Load(51) ->  24 Load(254) ->  53 Load(338) ->  34 Load(1945) ->  50 Load(2912) ->  0 Load(2912)
# Time of the route: 371
# Load of the route: 2912
#
# Route for vehicle 31:
#  0 Load(0) ->  38 Load(262) ->  37 Load(687) ->  42 Load(1321) ->  20 Load(1470) ->  7 Load(1741) ->  45 Load(2222) ->  9 Load(2750) ->  21 Load(2962) ->  0 Load(2962)
# Time of the route: 557
# Load of the route: 2962
#
# Route for vehicle 32:
#  0 Load(0) ->  47 Load(721) ->  31 Load(1743) ->  49 Load(1914) ->  0 Load(1914)
# Time of the route: 225
# Load of the route: 1914
#
# Route for vehicle 33:
#  0 Load(0) ->  56 Load(929) ->  55 Load(1995) ->  30 Load(2595) ->  0 Load(2595)
# Time of the route: 245
# Load of the route: 2595
#
# Route for vehicle 34:
#  0 Load(0) ->  22 Load(676) ->  23 Load(1425) ->  10 Load(2157) ->  0 Load(2157)
# Time of the route: 222
# Load of the route: 2157
#
# Total time of all routes: 72.2
# Total load of all routes: 32472
# Week 3
# Objective: 3803
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 22:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 23:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 24:
#  0 Load(0) ->  40 Load(179) ->  30 Load(418) ->  15 Load(646) ->  32 Load(1781) ->  12 Load(2216) ->  14 Load(2457) ->  46 Load(2640) ->  0 Load(2640)
# Time of the route: 546
# Load of the route: 2640
#
# Route for vehicle 25:
#  0 Load(0) ->  2 Load(498) ->  3 Load(1045) ->  36 Load(1159) ->  8 Load(1450) ->  29 Load(1999) ->  22 Load(2686) ->  7 Load(2957) ->  0 Load(2957)
# Time of the route: 543
# Load of the route: 2957
#
# Route for vehicle 26:
#  0 Load(0) ->  25 Load(293) ->  28 Load(531) ->  18 Load(2008) ->  24 Load(2668) ->  6 Load(2853) ->  0 Load(2853)
# Time of the route: 422
# Load of the route: 2853
#
# Route for vehicle 27:
#  0 Load(0) ->  13 Load(1147) ->  43 Load(1673) ->  39 Load(2781) ->  0 Load(2781)
# Time of the route: 260
# Load of the route: 2781
#
# Route for vehicle 28:
#  0 Load(0) ->  4 Load(102) ->  27 Load(479) ->  19 Load(866) ->  1 Load(1553) ->  34 Load(1843) ->  26 Load(2593) ->  20 Load(2736) ->  0 Load(2736)
# Time of the route: 517
# Load of the route: 2736
#
# Route for vehicle 29:
#  0 Load(0) ->  23 Load(2642) ->  0 Load(2642)
# Time of the route: 120
# Load of the route: 2642
#
# Route for vehicle 30:
#  0 Load(0) ->  33 Load(3000) ->  0 Load(3000)
# Time of the route: 119
# Load of the route: 3000
#
# Route for vehicle 31:
#  0 Load(0) ->  42 Load(834) ->  31 Load(1889) ->  44 Load(2643) ->  11 Load(2694) ->  0 Load(2694)
# Time of the route: 296
# Load of the route: 2694
#
# Route for vehicle 32:
#  0 Load(0) ->  9 Load(528) ->  38 Load(920) ->  37 Load(1490) ->  21 Load(2166) ->  35 Load(2319) ->  5 Load(2780) ->  0 Load(2780)
# Time of the route: 417
# Load of the route: 2780
#
# Route for vehicle 33:
#  0 Load(0) ->  16 Load(909) ->  48 Load(1336) ->  17 Load(2016) ->  47 Load(2310) ->  45 Load(2983) ->  0 Load(2983)
# Time of the route: 400
# Load of the route: 2983
#
# Route for vehicle 34:
#  0 Load(0) ->  41 Load(1134) ->  10 Load(1866) ->  0 Load(1866)
# Time of the route: 163
# Load of the route: 1866
#
# Total time of all routes: 63.4
# Total load of all routes: 29932
# Week 4
# Objective: 4477
# Route for vehicle 0:
#  0 Load(0) ->  43 Load(634) ->  7 Load(905) ->  6 Load(1090) ->  37 Load(1380) ->  38 Load(1805) ->  4 Load(1907) ->  39 Load(2169) ->  5 Load(2630) ->  0 Load(2630)
# Time of the route: 570
# Load of the route: 2630
#
# Route for vehicle 1:
#  0 Load(0) ->  14 Load(241) ->  12 Load(676) ->  15 Load(904) ->  49 Load(1076) ->  23 Load(2821) ->  20 Load(2962) ->  0 Load(2962)
# Time of the route: 493
# Load of the route: 2962
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 22:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 23:
#  0 Load(0) ->  2 Load(498) ->  18 Load(885) ->  8 Load(1176) ->  44 Load(1467) ->  30 Load(2978) ->  0 Load(2978)
# Time of the route: 420
# Load of the route: 2978
#
# Route for vehicle 24:
#  0 Load(0) ->  1 Load(687) ->  36 Load(1553) ->  29 Load(2127) ->  3 Load(2674) ->  41 Load(2982) ->  0 Load(2982)
# Time of the route: 399
# Load of the route: 2982
#
# Route for vehicle 25:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 26:
#  0 Load(0) ->  40 Load(1512) ->  19 Load(1899) ->  27 Load(2175) ->  28 Load(2739) ->  42 Load(2917) ->  0 Load(2917)
# Time of the route: 403
# Load of the route: 2917
#
# Route for vehicle 27:
#  0 Load(0) ->  11 Load(51) ->  46 Load(532) ->  51 Load(1499) ->  33 Load(2271) ->  17 Load(2951) ->  0 Load(2951)
# Time of the route: 398
# Load of the route: 2951
#
# Route for vehicle 28:
#  0 Load(0) ->  13 Load(1147) ->  53 Load(2106) ->  45 Load(2968) ->  0 Load(2968)
# Time of the route: 261
# Load of the route: 2968
#
# Route for vehicle 29:
#  0 Load(0) ->  55 Load(429) ->  25 Load(1105) ->  26 Load(2968) ->  0 Load(2968)
# Time of the route: 264
# Load of the route: 2968
#
# Route for vehicle 30:
#  0 Load(0) ->  35 Load(1607) ->  34 Load(2179) ->  52 Load(2423) ->  24 Load(2908) ->  0 Load(2908)
# Time of the route: 309
# Load of the route: 2908
#
# Route for vehicle 31:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 32:
#  0 Load(0) ->  10 Load(732) ->  47 Load(969) ->  22 Load(2368) ->  9 Load(2896) ->  0 Load(2896)
# Time of the route: 301
# Load of the route: 2896
#
# Route for vehicle 33:
#  0 Load(0) ->  48 Load(721) ->  50 Load(892) ->  32 Load(1914) ->  31 Load(2514) ->  21 Load(2871) ->  0 Load(2871)
# Time of the route: 354
# Load of the route: 2871
#
# Route for vehicle 34:
#  0 Load(0) ->  16 Load(909) ->  57 Load(1838) ->  56 Load(2904) ->  54 Load(2988) ->  0 Load(2988)
# Time of the route: 305
# Load of the route: 2988
#
# Total time of all routes: 74.6
# Total load of all routes: 35019
#
#
# South East
# Nodes served by week
# Week_1	Week_2	Week_3	Week_4
# 75	73	75	70
# Week 1
# Objective: 5819
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  2 Load(326) ->  36 Load(1816) ->  34 Load(2599) ->  0 Load(2599)
# Time of the route: 244
# Load of the route: 2599
#
# Route for vehicle 15:
#  0 Load(0) ->  15 Load(1190) ->  49 Load(1445) ->  48 Load(1789) ->  13 Load(2959) ->  0 Load(2959)
# Time of the route: 341
# Load of the route: 2959
#
# Route for vehicle 16:
#  0 Load(0) ->  43 Load(3000) ->  0 Load(3000)
# Time of the route: 138
# Load of the route: 3000
#
# Route for vehicle 17:
#  0 Load(0) ->  47 Load(1112) ->  45 Load(2807) ->  0 Load(2807)
# Time of the route: 197
# Load of the route: 2807
#
# Route for vehicle 18:
#  0 Load(0) ->  52 Load(255) ->  53 Load(582) ->  26 Load(1155) ->  21 Load(1942) ->  31 Load(2677) ->  0 Load(2677)
# Time of the route: 411
# Load of the route: 2677
#
# Route for vehicle 19:
#  0 Load(0) ->  27 Load(503) ->  29 Load(1673) ->  28 Load(2284) ->  51 Load(2404) ->  17 Load(2970) ->  0 Load(2970)
# Time of the route: 378
# Load of the route: 2970
#
# Route for vehicle 20:
#  0 Load(0) ->  37 Load(634) ->  5 Load(1719) ->  38 Load(2409) ->  3 Load(2781) ->  0 Load(2781)
# Time of the route: 303
# Load of the route: 2781
#
# Route for vehicle 21:
#  0 Load(0) ->  10 Load(1990) ->  41 Load(2654) ->  0 Load(2654)
# Time of the route: 179
# Load of the route: 2654
#
# Route for vehicle 22:
#  0 Load(0) ->  24 Load(1288) ->  25 Load(2226) ->  22 Load(2999) ->  0 Load(2999)
# Time of the route: 246
# Load of the route: 2999
#
# Route for vehicle 23:
#  0 Load(0) ->  12 Load(825) ->  9 Load(1492) ->  7 Load(2620) ->  35 Load(2863) ->  0 Load(2863)
# Time of the route: 333
# Load of the route: 2863
#
# Route for vehicle 24:
#  0 Load(0) ->  19 Load(582) ->  20 Load(1306) ->  18 Load(2276) ->  23 Load(2650) ->  0 Load(2650)
# Time of the route: 306
# Load of the route: 2650
#
# Route for vehicle 25:
#  0 Load(0) ->  50 Load(433) ->  32 Load(977) ->  57 Load(1347) ->  11 Load(1971) ->  44 Load(2433) ->  42 Load(3000) ->  0 Load(3000)
# Time of the route: 450
# Load of the route: 3000
#
# Route for vehicle 26:
#  0 Load(0) ->  40 Load(657) ->  39 Load(1086) ->  1 Load(1925) ->  70 Load(2756) ->  0 Load(2756)
# Time of the route: 295
# Load of the route: 2756
#
# Route for vehicle 27:
#  0 Load(0) ->  14 Load(77) ->  46 Load(2928) ->  0 Load(2928)
# Time of the route: 170
# Load of the route: 2928
#
# Route for vehicle 28:
#  0 Load(0) ->  67 Load(786) ->  68 Load(1526) ->  65 Load(2307) ->  66 Load(2913) ->  0 Load(2913)
# Time of the route: 302
# Load of the route: 2913
#
# Route for vehicle 29:
#  0 Load(0) ->  58 Load(587) ->  59 Load(1573) ->  56 Load(2821) ->  0 Load(2821)
# Time of the route: 231
# Load of the route: 2821
#
# Route for vehicle 30:
#  0 Load(0) ->  69 Load(554) ->  64 Load(1083) ->  63 Load(1888) ->  33 Load(2863) ->  0 Load(2863)
# Time of the route: 299
# Load of the route: 2863
#
# Route for vehicle 31:
#  0 Load(0) ->  62 Load(526) ->  61 Load(1052) ->  16 Load(2289) ->  60 Load(2992) ->  0 Load(2992)
# Time of the route: 278
# Load of the route: 2992
#
# Route for vehicle 32:
#  0 Load(0) ->  54 Load(785) ->  6 Load(1249) ->  4 Load(1754) ->  8 Load(2435) ->  0 Load(2435)
# Time of the route: 287
# Load of the route: 2435
#
# Route for vehicle 33:
#  0 Load(0) ->  73 Load(1052) ->  72 Load(1465) ->  55 Load(2290) ->  0 Load(2290)
# Time of the route: 220
# Load of the route: 2290
#
# Route for vehicle 34:
#  0 Load(0) ->  74 Load(475) ->  30 Load(2133) ->  71 Load(2820) ->  0 Load(2820)
# Time of the route: 211
# Load of the route: 2820
#
# Total time of all routes: 97.0
# Total load of all routes: 58777
# Week 2
# Objective: 5558
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  47 Load(3000) ->  0 Load(3000)
# Time of the route: 148
# Load of the route: 3000
#
# Route for vehicle 18:
#  0 Load(0) ->  44 Load(119) ->  42 Load(593) ->  9 Load(1260) ->  41 Load(1796) ->  7 Load(2924) ->  0 Load(2924)
# Time of the route: 398
# Load of the route: 2924
#
# Route for vehicle 19:
#  0 Load(0) ->  15 Load(1190) ->  13 Load(2360) ->  43 Load(2997) ->  0 Load(2997)
# Time of the route: 266
# Load of the route: 2997
#
# Route for vehicle 20:
#  0 Load(0) ->  51 Load(12) ->  17 Load(578) ->  21 Load(1365) ->  12 Load(2190) ->  11 Load(2814) ->  49 Load(2961) ->  0 Load(2961)
# Time of the route: 470
# Load of the route: 2961
#
# Route for vehicle 21:
#  0 Load(0) ->  69 Load(695) ->  27 Load(1198) ->  29 Load(2368) ->  28 Load(2979) ->  0 Load(2979)
# Time of the route: 314
# Load of the route: 2979
#
# Route for vehicle 22:
#  0 Load(0) ->  23 Load(374) ->  26 Load(947) ->  37 Load(1494) ->  58 Load(2041) ->  57 Load(2773) ->  0 Load(2773)
# Time of the route: 384
# Load of the route: 2773
#
# Route for vehicle 23:
#  0 Load(0) ->  40 Load(1161) ->  5 Load(2246) ->  38 Load(2804) ->  0 Load(2804)
# Time of the route: 254
# Load of the route: 2804
#
# Route for vehicle 24:
#  0 Load(0) ->  46 Load(367) ->  35 Load(1008) ->  10 Load(2998) ->  0 Load(2998)
# Time of the route: 260
# Load of the route: 2998
#
# Route for vehicle 25:
#  0 Load(0) ->  53 Load(848) ->  22 Load(1621) ->  55 Load(2237) ->  56 Load(2797) ->  54 Load(2960) ->  0 Load(2960)
# Time of the route: 369
# Load of the route: 2960
#
# Route for vehicle 26:
#  0 Load(0) ->  45 Load(1518) ->  33 Load(2524) ->  6 Load(2988) ->  0 Load(2988)
# Time of the route: 240
# Load of the route: 2988
#
# Route for vehicle 27:
#  0 Load(0) ->  24 Load(1288) ->  25 Load(2226) ->  52 Load(2951) ->  0 Load(2951)
# Time of the route: 244
# Load of the route: 2951
#
# Route for vehicle 28:
#  0 Load(0) ->  19 Load(582) ->  20 Load(1306) ->  18 Load(2276) ->  36 Load(2982) ->  0 Load(2982)
# Time of the route: 302
# Load of the route: 2982
#
# Route for vehicle 29:
#  0 Load(0) ->  1 Load(839) ->  2 Load(1165) ->  39 Load(1799) ->  3 Load(2171) ->  31 Load(2969) ->  0 Load(2969)
# Time of the route: 360
# Load of the route: 2969
#
# Route for vehicle 30:
#  0 Load(0) ->  66 Load(331) ->  48 Load(585) ->  63 Load(1121) ->  62 Load(2171) ->  60 Load(2954) ->  0 Load(2954)
# Time of the route: 355
# Load of the route: 2954
#
# Route for vehicle 31:
#  0 Load(0) ->  72 Load(306) ->  34 Load(1591) ->  0 Load(1591)
# Time of the route: 165
# Load of the route: 1591
#
# Route for vehicle 32:
#  0 Load(0) ->  67 Load(904) ->  64 Load(1248) ->  65 Load(1810) ->  61 Load(2865) ->  0 Load(2865)
# Time of the route: 278
# Load of the route: 2865
#
# Route for vehicle 33:
#  0 Load(0) ->  70 Load(221) ->  8 Load(902) ->  32 Load(1301) ->  59 Load(1825) ->  4 Load(2330) ->  30 Load(2692) ->  71 Load(2916) ->  0 Load(2916)
# Time of the route: 470
# Load of the route: 2916
#
# Route for vehicle 34:
#  0 Load(0) ->  14 Load(77) ->  16 Load(1314) ->  50 Load(1726) ->  68 Load(2578) ->  0 Load(2578)
# Time of the route: 281
# Load of the route: 2578
#
# Total time of all routes: 92.6
# Total load of all routes: 51190
# Week 3
# Objective: 5795
# Route for vehicle 0:
#  0 Load(0) ->  57 Load(370) ->  17 Load(936) ->  50 Load(1369) ->  21 Load(2156) ->  51 Load(2276) ->  26 Load(2849) ->  0 Load(2849)
# Time of the route: 473
# Load of the route: 2849
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  13 Load(1170) ->  9 Load(1837) ->  31 Load(2765) ->  0 Load(2765)
# Time of the route: 268
# Load of the route: 2765
#
# Route for vehicle 16:
#  0 Load(0) ->  43 Load(3000) ->  0 Load(3000)
# Time of the route: 138
# Load of the route: 3000
#
# Route for vehicle 17:
#  0 Load(0) ->  47 Load(1112) ->  45 Load(2807) ->  0 Load(2807)
# Time of the route: 197
# Load of the route: 2807
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  15 Load(1190) ->  48 Load(1534) ->  12 Load(2359) ->  11 Load(2983) ->  0 Load(2983)
# Time of the route: 339
# Load of the route: 2983
#
# Route for vehicle 20:
#  0 Load(0) ->  52 Load(255) ->  28 Load(866) ->  29 Load(2036) ->  53 Load(2363) ->  27 Load(2866) ->  0 Load(2866)
# Time of the route: 377
# Load of the route: 2866
#
# Route for vehicle 21:
#  0 Load(0) ->  38 Load(690) ->  34 Load(1473) ->  36 Load(2963) ->  0 Load(2963)
# Time of the route: 245
# Load of the route: 2963
#
# Route for vehicle 22:
#  0 Load(0) ->  18 Load(970) ->  25 Load(1908) ->  22 Load(2681) ->  49 Load(2936) ->  0 Load(2936)
# Time of the route: 339
# Load of the route: 2936
#
# Route for vehicle 23:
#  0 Load(0) ->  44 Load(462) ->  10 Load(2452) ->  6 Load(2916) ->  0 Load(2916)
# Time of the route: 240
# Load of the route: 2916
#
# Route for vehicle 24:
#  0 Load(0) ->  37 Load(634) ->  5 Load(1719) ->  2 Load(2045) ->  1 Load(2884) ->  0 Load(2884)
# Time of the route: 302
# Load of the route: 2884
#
# Route for vehicle 25:
#  0 Load(0) ->  19 Load(582) ->  20 Load(1306) ->  24 Load(2594) ->  23 Load(2968) ->  0 Load(2968)
# Time of the route: 307
# Load of the route: 2968
#
# Route for vehicle 26:
#  0 Load(0) ->  41 Load(664) ->  42 Load(1231) ->  7 Load(2359) ->  35 Load(2602) ->  3 Load(2974) ->  0 Load(2974)
# Time of the route: 387
# Load of the route: 2974
#
# Route for vehicle 27:
#  0 Load(0) ->  14 Load(77) ->  46 Load(2928) ->  0 Load(2928)
# Time of the route: 170
# Load of the route: 2928
#
# Route for vehicle 28:
#  0 Load(0) ->  67 Load(786) ->  69 Load(1340) ->  33 Load(2081) ->  68 Load(2821) ->  0 Load(2821)
# Time of the route: 298
# Load of the route: 2821
#
# Route for vehicle 29:
#  0 Load(0) ->  65 Load(781) ->  66 Load(1387) ->  64 Load(1916) ->  32 Load(2136) ->  63 Load(2941) ->  0 Load(2941)
# Time of the route: 357
# Load of the route: 2941
#
# Route for vehicle 30:
#  0 Load(0) ->  58 Load(587) ->  59 Load(1573) ->  56 Load(2821) ->  0 Load(2821)
# Time of the route: 231
# Load of the route: 2821
#
# Route for vehicle 31:
#  0 Load(0) ->  54 Load(785) ->  4 Load(1290) ->  39 Load(1719) ->  30 Load(2050) ->  40 Load(2707) ->  0 Load(2707)
# Time of the route: 352
# Load of the route: 2707
#
# Route for vehicle 32:
#  0 Load(0) ->  62 Load(526) ->  61 Load(1052) ->  16 Load(2289) ->  60 Load(2992) ->  0 Load(2992)
# Time of the route: 278
# Load of the route: 2992
#
# Route for vehicle 33:
#  0 Load(0) ->  70 Load(831) ->  8 Load(1512) ->  55 Load(2337) ->  0 Load(2337)
# Time of the route: 222
# Load of the route: 2337
#
# Route for vehicle 34:
#  0 Load(0) ->  74 Load(475) ->  73 Load(1527) ->  72 Load(1940) ->  71 Load(2627) ->  0 Load(2627)
# Time of the route: 275
# Load of the route: 2627
#
# Total time of all routes: 96.6
# Total load of all routes: 57085
# Week 4
# Objective: 5389
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  44 Load(3000) ->  0 Load(3000)
# Time of the route: 148
# Load of the route: 3000
#
# Route for vehicle 18:
#  0 Load(0) ->  48 Load(12) ->  21 Load(799) ->  43 Load(1166) ->  9 Load(1833) ->  37 Load(2994) ->  0 Load(2994)
# Time of the route: 413
# Load of the route: 2994
#
# Route for vehicle 19:
#  0 Load(0) ->  39 Load(474) ->  41 Load(593) ->  13 Load(1763) ->  15 Load(2953) ->  0 Load(2953)
# Time of the route: 330
# Load of the route: 2953
#
# Route for vehicle 20:
#  0 Load(0) ->  54 Load(732) ->  55 Load(1279) ->  34 Load(1826) ->  26 Load(2399) ->  17 Load(2965) ->  0 Load(2965)
# Time of the route: 386
# Load of the route: 2965
#
# Route for vehicle 21:
#  0 Load(0) ->  46 Load(147) ->  38 Load(683) ->  7 Load(1811) ->  5 Load(2896) ->  0 Load(2896)
# Time of the route: 331
# Load of the route: 2896
#
# Route for vehicle 22:
#  0 Load(0) ->  23 Load(374) ->  27 Load(877) ->  29 Load(2047) ->  28 Load(2658) ->  51 Load(2821) ->  0 Load(2821)
# Time of the route: 376
# Load of the route: 2821
#
# Route for vehicle 23:
#  0 Load(0) ->  22 Load(773) ->  53 Load(1333) ->  52 Load(1949) ->  25 Load(2887) ->  0 Load(2887)
# Time of the route: 310
# Load of the route: 2887
#
# Route for vehicle 24:
#  0 Load(0) ->  45 Load(254) ->  10 Load(2244) ->  11 Load(2868) ->  0 Load(2868)
# Time of the route: 250
# Load of the route: 2868
#
# Route for vehicle 25:
#  0 Load(0) ->  40 Load(637) ->  12 Load(1462) ->  42 Load(2980) ->  0 Load(2980)
# Time of the route: 266
# Load of the route: 2980
#
# Route for vehicle 26:
#  0 Load(0) ->  2 Load(326) ->  32 Load(2977) ->  0 Load(2977)
# Time of the route: 178
# Load of the route: 2977
#
# Route for vehicle 27:
#  0 Load(0) ->  1 Load(839) ->  30 Load(1653) ->  35 Load(2211) ->  36 Load(2845) ->  0 Load(2845)
# Time of the route: 302
# Load of the route: 2845
#
# Route for vehicle 28:
#  0 Load(0) ->  19 Load(582) ->  18 Load(1552) ->  50 Load(2400) ->  62 Load(2962) ->  0 Load(2962)
# Time of the route: 302
# Load of the route: 2962
#
# Route for vehicle 29:
#  0 Load(0) ->  66 Load(695) ->  24 Load(1983) ->  33 Load(2245) ->  20 Load(2969) ->  0 Load(2969)
# Time of the route: 301
# Load of the route: 2969
#
# Route for vehicle 30:
#  0 Load(0) ->  49 Load(725) ->  63 Load(1056) ->  59 Load(2106) ->  60 Load(2642) ->  68 Load(2866) ->  0 Load(2866)
# Time of the route: 362
# Load of the route: 2866
#
# Route for vehicle 31:
#  0 Load(0) ->  57 Load(783) ->  56 Load(1307) ->  4 Load(1812) ->  3 Load(2184) ->  6 Load(2648) ->  0 Load(2648)
# Time of the route: 353
# Load of the route: 2648
#
# Route for vehicle 32:
#  0 Load(0) ->  64 Load(904) ->  61 Load(1248) ->  58 Load(2303) ->  0 Load(2303)
# Time of the route: 217
# Load of the route: 2303
#
# Route for vehicle 33:
#  0 Load(0) ->  67 Load(221) ->  8 Load(902) ->  31 Load(2686) ->  0 Load(2686)
# Time of the route: 222
# Load of the route: 2686
#
# Route for vehicle 34:
#  0 Load(0) ->  69 Load(306) ->  14 Load(383) ->  16 Load(1620) ->  47 Load(2032) ->  65 Load(2884) ->  0 Load(2884)
# Time of the route: 342
# Load of the route: 2884
#
# Total time of all routes: 89.8
# Total load of all routes: 51504
# South West
# Nodes served by week
# Week_1	Week_2	Week_3	Week_4
# 46	58	46	55
# Week 1
# Objective: 3526
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 22:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 23:
#  0 Load(0) ->  38 Load(534) ->  16 Load(2656) ->  14 Load(2910) ->  0 Load(2910)
# Time of the route: 250
# Load of the route: 2910
#
# Route for vehicle 24:
#  0 Load(0) ->  17 Load(1341) ->  39 Load(2610) ->  18 Load(2957) ->  0 Load(2957)
# Time of the route: 258
# Load of the route: 2957
#
# Route for vehicle 25:
#  0 Load(0) ->  3 Load(490) ->  10 Load(1083) ->  15 Load(1295) ->  37 Load(1522) ->  22 Load(2471) ->  33 Load(2920) ->  0 Load(2920)
# Time of the route: 442
# Load of the route: 2920
#
# Route for vehicle 26:
#  0 Load(0) ->  31 Load(637) ->  30 Load(1789) ->  6 Load(2888) ->  0 Load(2888)
# Time of the route: 246
# Load of the route: 2888
#
# Route for vehicle 27:
#  0 Load(0) ->  42 Load(531) ->  40 Load(916) ->  45 Load(2347) ->  19 Load(2692) ->  0 Load(2692)
# Time of the route: 316
# Load of the route: 2692
#
# Route for vehicle 28:
#  0 Load(0) ->  44 Load(644) ->  21 Load(1117) ->  13 Load(1706) ->  36 Load(2723) ->  0 Load(2723)
# Time of the route: 315
# Load of the route: 2723
#
# Route for vehicle 29:
#  0 Load(0) ->  20 Load(307) ->  12 Load(516) ->  35 Load(1567) ->  43 Load(2344) ->  41 Load(2937) ->  0 Load(2937)
# Time of the route: 374
# Load of the route: 2937
#
# Route for vehicle 30:
#  0 Load(0) ->  26 Load(968) ->  4 Load(1679) ->  27 Load(2313) ->  28 Load(2462) ->  32 Load(2836) ->  23 Load(2996) ->  0 Load(2996)
# Time of the route: 431
# Load of the route: 2996
#
# Route for vehicle 31:
#  0 Load(0) ->  25 Load(854) ->  29 Load(1353) ->  34 Load(1865) ->  11 Load(2988) ->  0 Load(2988)
# Time of the route: 304
# Load of the route: 2988
#
# Route for vehicle 32:
#  0 Load(0) ->  7 Load(439) ->  8 Load(1102) ->  9 Load(1899) ->  5 Load(2756) ->  0 Load(2756)
# Time of the route: 324
# Load of the route: 2756
#
# Route for vehicle 33:
#  0 Load(0) ->  1 Load(1071) ->  2 Load(2412) ->  0 Load(2412)
# Time of the route: 166
# Load of the route: 2412
#
# Route for vehicle 34:
#  0 Load(0) ->  24 Load(2129) ->  0 Load(2129)
# Time of the route: 100
# Load of the route: 2129
#
# Total time of all routes: 58.8
# Total load of all routes: 33308
# Week 2
# Objective: 4327
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  52 Load(294) ->  24 Load(1336) ->  14 Load(1590) ->  48 Load(1757) ->  42 Load(2741) ->  0 Load(2741)
# Time of the route: 390
# Load of the route: 2741
#
# Route for vehicle 22:
#  0 Load(0) ->  46 Load(613) ->  47 Load(836) ->  16 Load(2958) ->  0 Load(2958)
# Time of the route: 252
# Load of the route: 2958
#
# Route for vehicle 23:
#  0 Load(0) ->  12 Load(209) ->  44 Load(594) ->  15 Load(806) ->  17 Load(2147) ->  45 Load(2850) ->  0 Load(2850)
# Time of the route: 377
# Load of the route: 2850
#
# Route for vehicle 24:
#  0 Load(0) ->  23 Load(889) ->  22 Load(1077) ->  55 Load(1451) ->  2 Load(2792) ->  0 Load(2792)
# Time of the route: 306
# Load of the route: 2792
#
# Route for vehicle 25:
#  0 Load(0) ->  28 Load(729) ->  34 Load(825) ->  32 Load(1948) ->  37 Load(2456) ->  53 Load(2972) ->  0 Load(2972)
# Time of the route: 373
# Load of the route: 2972
#
# Route for vehicle 26:
#  0 Load(0) ->  43 Load(385) ->  41 Load(825) ->  38 Load(1216) ->  57 Load(1526) ->  31 Load(2985) ->  0 Load(2985)
# Time of the route: 372
# Load of the route: 2985
#
# Route for vehicle 27:
#  0 Load(0) ->  36 Load(353) ->  10 Load(946) ->  13 Load(1535) ->  11 Load(2658) ->  0 Load(2658)
# Time of the route: 309
# Load of the route: 2658
#
# Route for vehicle 28:
#  0 Load(0) ->  54 Load(360) ->  33 Load(1041) ->  6 Load(2140) ->  4 Load(2851) ->  0 Load(2851)
# Time of the route: 304
# Load of the route: 2851
#
# Route for vehicle 29:
#  0 Load(0) ->  40 Load(617) ->  9 Load(1414) ->  39 Load(2124) ->  8 Load(2787) ->  0 Load(2787)
# Time of the route: 296
# Load of the route: 2787
#
# Route for vehicle 30:
#  0 Load(0) ->  5 Load(857) ->  35 Load(2467) ->  56 Load(2987) ->  0 Load(2987)
# Time of the route: 234
# Load of the route: 2987
#
# Route for vehicle 31:
#  0 Load(0) ->  1 Load(1071) ->  50 Load(1596) ->  49 Load(1849) ->  0 Load(1849)
# Time of the route: 221
# Load of the route: 1849
#
# Route for vehicle 32:
#  0 Load(0) ->  7 Load(439) ->  20 Load(898) ->  3 Load(1388) ->  21 Load(2187) ->  30 Load(2707) ->  0 Load(2707)
# Time of the route: 385
# Load of the route: 2707
#
# Route for vehicle 33:
#  0 Load(0) ->  19 Load(55) ->  26 Load(1111) ->  25 Load(1890) ->  0 Load(1890)
# Time of the route: 220
# Load of the route: 1890
#
# Route for vehicle 34:
#  0 Load(0) ->  27 Load(659) ->  29 Load(2098) ->  51 Load(2472) ->  18 Load(2839) ->  0 Load(2839)
# Time of the route: 288
# Load of the route: 2839
#
# Total time of all routes: 72.1
# Total load of all routes: 37866
# Week 3
# Objective: 3561
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 22:
#  0 Load(0) ->  14 Load(254) ->  41 Load(847) ->  16 Load(2969) ->  0 Load(2969)
# Time of the route: 251
# Load of the route: 2969
#
# Route for vehicle 23:
#  0 Load(0) ->  35 Load(1051) ->  43 Load(1828) ->  42 Load(2359) ->  33 Load(2808) ->  0 Load(2808)
# Time of the route: 310
# Load of the route: 2808
#
# Route for vehicle 24:
#  0 Load(0) ->  12 Load(209) ->  15 Load(421) ->  37 Load(648) ->  38 Load(1182) ->  40 Load(1567) ->  39 Load(2836) ->  0 Load(2836)
# Time of the route: 440
# Load of the route: 2836
#
# Route for vehicle 25:
#  0 Load(0) ->  13 Load(589) ->  36 Load(1606) ->  17 Load(2947) ->  0 Load(2947)
# Time of the route: 259
# Load of the route: 2947
#
# Route for vehicle 26:
#  0 Load(0) ->  26 Load(968) ->  28 Load(1117) ->  27 Load(1751) ->  4 Load(2462) ->  0 Load(2462)
# Time of the route: 301
# Load of the route: 2462
#
# Route for vehicle 27:
#  0 Load(0) ->  3 Load(490) ->  44 Load(1134) ->  29 Load(1633) ->  25 Load(2487) ->  19 Load(2876) ->  0 Load(2876)
# Time of the route: 359
# Load of the route: 2876
#
# Route for vehicle 28:
#  0 Load(0) ->  31 Load(637) ->  21 Load(1294) ->  45 Load(2725) ->  0 Load(2725)
# Time of the route: 247
# Load of the route: 2725
#
# Route for vehicle 29:
#  0 Load(0) ->  30 Load(1152) ->  6 Load(2251) ->  32 Load(2625) ->  23 Load(2785) ->  0 Load(2785)
# Time of the route: 307
# Load of the route: 2785
#
# Route for vehicle 30:
#  0 Load(0) ->  7 Load(439) ->  8 Load(1102) ->  9 Load(1899) ->  5 Load(2756) ->  0 Load(2756)
# Time of the route: 324
# Load of the route: 2756
#
# Route for vehicle 31:
#  0 Load(0) ->  22 Load(1835) ->  18 Load(2561) ->  0 Load(2561)
# Time of the route: 193
# Load of the route: 2561
#
# Route for vehicle 32:
# ...
# Time of the route: 250
# Load of the route: 1647
#
# Route for vehicle 27:
#  0 Load(0) ->  34 Load(690) ->  35 Load(1160) ->  73 Load(1686) ->  37 Load(2228) ->  36 Load(2471) ->  43 Load(2688) ->  42 Load(2881) ->  0 Load(2881)
# Time of the route: 482
# Load of the route: 2881
#
# Route for vehicle 28:
#  0 Load(0) ->  49 Load(694) ->  22 Load(984) ->  16 Load(1944) ->  14 Load(2405) ->  47 Load(2957) ->  0 Load(2957)
# Time of the route: 328
# Load of the route: 2957
#
# Route for vehicle 29:
#  0 Load(0) ->  26 Load(192) ->  25 Load(384) ->  65 Load(691) ->  30 Load(956) ->  31 Load(1642) ->  29 Load(1949) ->  51 Load(2583) ->  0 Load(2583)
# Time of the route: 444
# Load of the route: 2583
#
# Route for vehicle 30:
#  0 Load(0) ->  44 Load(408) ->  3 Load(1075) ->  1 Load(1442) ->  55 Load(1717) ->  7 Load(2160) ->  8 Load(2956) ->  0 Load(2956)
# Time of the route: 396
# Load of the route: 2956
#
# Route for vehicle 31:
#  0 Load(0) ->  10 Load(801) ->  13 Load(1556) ->  57 Load(2298) ->  41 Load(2888) ->  0 Load(2888)
# Time of the route: 257
# Load of the route: 2888
#
# Route for vehicle 32:
#  0 Load(0) ->  17 Load(884) ->  18 Load(1315) ->  19 Load(1817) ->  21 Load(2387) ->  24 Load(2579) ->  0 Load(2579)
# Time of the route: 326
# Load of the route: 2579
#
# Route for vehicle 33:
#  0 Load(0) ->  59 Load(540) ->  60 Load(2011) ->  46 Load(2308) ->  11 Load(2778) ->  0 Load(2778)
# Time of the route: 250
# Load of the route: 2778
#
# Route for vehicle 34:
#  0 Load(0) ->  32 Load(1062) ->  28 Load(1816) ->  27 Load(2062) ->  69 Load(2255) ->  39 Load(2467) ->  12 Load(2673) ->  9 Load(2805) ->  0 Load(2805)
# Time of the route: 473
# Load of the route: 2805
#
# Total time of all routes: 80.8
# Total load of all routes: 38273
# Week 2
# Objective: 5607
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  84 Load(374) ->  83 Load(1595) ->  27 Load(1841) ->  78 Load(1991) ->  76 Load(2967) ->  0 Load(2967)
# Time of the route: 375
# Load of the route: 2967
#
# Route for vehicle 21:
#  0 Load(0) ->  28 Load(754) ->  34 Load(1444) ->  35 Load(1914) ->  37 Load(2456) ->  36 Load(2699) ->  45 Load(2880) ->  0 Load(2880)
# Time of the route: 422
# Load of the route: 2880
#
# Route for vehicle 22:
#  0 Load(0) ->  41 Load(639) ->  6 Load(774) ->  4 Load(1272) ->  38 Load(2294) ->  1 Load(2661) ->  77 Load(2981) ->  0 Load(2981)
# Time of the route: 423
# Load of the route: 2981
#
# Route for vehicle 23:
#  0 Load(0) ->  14 Load(461) ->  51 Load(1326) ->  73 Load(2220) ->  67 Load(2726) ->  0 Load(2726)
# Time of the route: 271
# Load of the route: 2726
#
# Route for vehicle 24:
#  0 Load(0) ->  57 Load(516) ->  58 Load(678) ->  44 Load(1485) ->  32 Load(2547) ->  33 Load(2980) ->  0 Load(2980)
# Time of the route: 351
# Load of the route: 2980
#
# Route for vehicle 25:
#  0 Load(0) ->  17 Load(884) ->  19 Load(1386) ->  16 Load(2346) ->  21 Load(2916) ->  0 Load(2916)
# Time of the route: 267
# Load of the route: 2916
#
# Route for vehicle 26:
#  0 Load(0) ->  15 Load(806) ->  48 Load(1221) ->  5 Load(2226) ->  46 Load(2970) ->  0 Load(2970)
# Time of the route: 277
# Load of the route: 2970
#
# Route for vehicle 27:
#  0 Load(0) ->  82 Load(574) ->  43 Load(1251) ->  81 Load(1884) ->  80 Load(2041) ->  79 Load(2282) ->  75 Load(2962) ->  0 Load(2962)
# Time of the route: 402
# Load of the route: 2962
#
# Route for vehicle 28:
#  0 Load(0) ->  10 Load(801) ->  62 Load(989) ->  61 Load(1464) ->  39 Load(1829) ->  65 Load(2057) ->  42 Load(2703) ->  72 Load(2835) ->  0 Load(2835)
# Time of the route: 454
# Load of the route: 2835
#
# Route for vehicle 29:
#  0 Load(0) ->  18 Load(431) ->  54 Load(1515) ->  22 Load(1805) ->  52 Load(2623) ->  53 Load(2748) ->  24 Load(2940) ->  0 Load(2940)
# Time of the route: 390
# Load of the route: 2940
#
# Route for vehicle 30:
#  0 Load(0) ->  9 Load(132) ->  12 Load(338) ->  64 Load(387) ->  2 Load(1201) ->  3 Load(1868) ->  59 Load(2214) ->  60 Load(2848) ->  0 Load(2848)
# Time of the route: 455
# Load of the route: 2848
#
# Route for vehicle 31:
#  0 Load(0) ->  70 Load(183) ->  66 Load(1485) ->  47 Load(2314) ->  63 Load(2840) ->  40 Load(2994) ->  0 Load(2994)
# Time of the route: 321
# Load of the route: 2994
#
# Route for vehicle 32:
#  0 Load(0) ->  71 Load(1141) ->  49 Load(1467) ->  13 Load(2222) ->  50 Load(2513) ->  11 Load(2983) ->  0 Load(2983)
# Time of the route: 320
# Load of the route: 2983
#
# Route for vehicle 33:
#  0 Load(0) ->  26 Load(192) ->  25 Load(384) ->  55 Load(1018) ->  31 Load(1704) ->  30 Load(1969) ->  29 Load(2276) ->  56 Load(2420) ->  74 Load(2970) ->  0 Load(2970)
# Time of the route: 502
# Load of the route: 2970
#
# Route for vehicle 34:
#  0 Load(0) ->  69 Load(268) ->  7 Load(711) ->  8 Load(1507) ->  68 Load(1840) ->  20 Load(2647) ->  23 Load(2992) ->  0 Load(2992)
# Time of the route: 377
# Load of the route: 2992
#
# Total time of all routes: 93.5
# Total load of all routes: 43944
# Week 3
# Objective: 5208
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  32 Load(1062) ->  36 Load(1305) ->  37 Load(1847) ->  47 Load(2488) ->  33 Load(2921) ->  0 Load(2921)
# Time of the route: 356
# Load of the route: 2921
#
# Route for vehicle 21:
#  0 Load(0) ->  48 Load(217) ->  78 Load(743) ->  35 Load(1213) ->  34 Load(1903) ->  27 Load(2149) ->  75 Load(2574) ->  69 Load(2700) ->  68 Load(2989) ->  0 Load(2989)
# Time of the route: 546
# Load of the route: 2989
#
# Route for vehicle 22:
#  0 Load(0) ->  28 Load(754) ->  77 Load(1900) ->  76 Load(2781) ->  9 Load(2913) ->  0 Load(2913)
# Time of the route: 282
# Load of the route: 2913
#
# Route for vehicle 23:
#  0 Load(0) ->  40 Load(597) ->  72 Load(1492) ->  73 Load(1537) ->  42 Load(1993) ->  43 Load(2995) ->  0 Load(2995)
# Time of the route: 352
# Load of the route: 2995
#
# Route for vehicle 24:
#  0 Load(0) ->  59 Load(462) ->  49 Load(870) ->  6 Load(1005) ->  50 Load(1421) ->  4 Load(1919) ->  5 Load(2924) ->  0 Load(2924)
# Time of the route: 406
# Load of the route: 2924
#
# Route for vehicle 25:
#  0 Load(0) ->  14 Load(461) ->  63 Load(2120) ->  15 Load(2926) ->  0 Load(2926)
# Time of the route: 210
# Load of the route: 2926
#
# Route for vehicle 26:
#  0 Load(0) ->  53 Load(163) ->  18 Load(594) ->  52 Load(1146) ->  16 Load(2106) ->  17 Load(2990) ->  0 Load(2990)
# Time of the route: 329
# Load of the route: 2990
#
# Route for vehicle 27:
#  0 Load(0) ->  57 Load(331) ->  58 Load(858) ->  0 Load(858)
# Time of the route: 142
# Load of the route: 858
#
# Route for vehicle 28:
#  0 Load(0) ->  70 Load(307) ->  22 Load(597) ->  44 Load(1216) ->  38 Load(2402) ->  19 Load(2904) ->  0 Load(2904)
# Time of the route: 331
# Load of the route: 2904
#
# Route for vehicle 29:
#  0 Load(0) ->  71 Load(765) ->  46 Load(1103) ->  30 Load(1368) ->  31 Load(2054) ->  29 Load(2361) ->  56 Load(2995) ->  0 Load(2995)
# Time of the route: 385
# Load of the route: 2995
#
# Route for vehicle 30:
#  0 Load(0) ->  7 Load(443) ->  8 Load(1239) ->  12 Load(1445) ->  2 Load(2259) ->  3 Load(2926) ->  0 Load(2926)
# Time of the route: 328
# Load of the route: 2926
#
# Route for vehicle 31:
#  0 Load(0) ->  61 Load(163) ->  10 Load(964) ->  51 Load(1261) ->  13 Load(2016) ->  62 Load(2758) ->  0 Load(2758)
# Time of the route: 319
# Load of the route: 2758
#
# Route for vehicle 32:
#  0 Load(0) ->  26 Load(192) ->  25 Load(384) ->  21 Load(954) ->  54 Load(1648) ->  45 Load(2282) ->  55 Load(2715) ->  24 Load(2907) ->  0 Load(2907)
# Time of the route: 448
# Load of the route: 2907
#
# Route for vehicle 33:
#  0 Load(0) ->  64 Load(540) ->  65 Load(2011) ->  11 Load(2481) ->  0 Load(2481)
# Time of the route: 190
# Load of the route: 2481
#
# Route for vehicle 34:
#  0 Load(0) ->  23 Load(345) ->  20 Load(1152) ->  66 Load(1369) ->  67 Load(1703) ->  74 Load(1896) ->  41 Load(2114) ->  1 Load(2481) ->  39 Load(2683) ->  60 Load(2958) ->  0 Load(2958)
# Time of the route: 584
# Load of the route: 2958
#
# Total time of all routes: 86.8
# Total load of all routes: 41445
# Week 4
# Objective: 5309
# Route for vehicle 0:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 1:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 2:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 3:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 4:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 5:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 6:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 7:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 8:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 9:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 10:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 11:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 12:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 13:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 14:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 15:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 16:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 17:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 18:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 19:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 20:
#  0 Load(0) ->  0 Load(0)
# Time of the route: 0
# Load of the route: 0
#
# Route for vehicle 21:
#  0 Load(0) ->  36 Load(243) ->  79 Load(1464) ->  35 Load(1934) ->  37 Load(2476) ->  80 Load(2850) ->  0 Load(2850)
# Time of the route: 353
# Load of the route: 2850
#
# Route for vehicle 22:
#  0 Load(0) ->  52 Load(144) ->  53 Load(660) ->  54 Load(822) ->  41 Load(1003) ->  40 Load(1523) ->  34 Load(2213) ->  71 Load(2893) ->  0 Load(2893)
# Time of the route: 488
# Load of the route: 2893
#
# Route for vehicle 23:
#  0 Load(0) ->  16 Load(960) ->  44 Load(1375) ->  4 Load(1873) ->  5 Load(2878) ->  0 Load(2878)
# Time of the route: 276
# Load of the route: 2878
#
# Route for vehicle 24:
#  0 Load(0) ->  6 Load(135) ->  15 Load(941) ->  69 Load(1835) ->  47 Load(2700) ->  24 Load(2892) ->  0 Load(2892)
# Time of the route: 335
# Load of the route: 2892
#
# Route for vehicle 25:
#  0 Load(0) ->  17 Load(884) ->  19 Load(1386) ->  14 Load(1847) ->  63 Load(2353) ->  21 Load(2923) ->  0 Load(2923)
# Time of the route: 328
# Load of the route: 2923
#
# Route for vehicle 26:
#  0 Load(0) ->  78 Load(574) ->  77 Load(1207) ->  75 Load(1448) ->  32 Load(2510) ->  33 Load(2943) ->  0 Load(2943)
# Time of the route: 346
# Load of the route: 2943
#
# Route for vehicle 27:
#  0 Load(0) ->  28 Load(754) ->  76 Load(911) ->  27 Load(1157) ->  72 Load(2133) ->  56 Load(2767) ->  61 Load(2995) ->  0 Load(2995)
# Time of the route: 413
# Load of the route: 2995
#
# Route for vehicle 28:
#  0 Load(0) ->  66 Load(183) ->  62 Load(1485) ->  43 Load(2314) ->  59 Load(2840) ->  0 Load(2840)
# Time of the route: 261
# Load of the route: 2840
#
# Route for vehicle 29:
#  0 Load(0) ->  49 Load(125) ->  48 Load(943) ->  22 Load(1233) ->  50 Load(2317) ->  18 Load(2748) ->  0 Load(2748)
# Time of the route: 329
# Load of the route: 2748
#
# Route for vehicle 30:
#  0 Load(0) ->  9 Load(132) ->  12 Load(338) ->  60 Load(387) ->  38 Load(700) ->  58 Load(888) ->  57 Load(1363) ->  42 Load(2107) ->  10 Load(2908) ->  0 Load(2908)
# Time of the route: 513
# Load of the route: 2908
#
# Route for vehicle 31:
#  0 Load(0) ->  68 Load(132) ->  74 Load(282) ->  73 Load(602) ->  55 Load(948) ->  1 Load(1315) ->  2 Load(2129) ->  3 Load(2796) ->  0 Load(2796)
# Time of the route: 468
# Load of the route: 2796
#
# Route for vehicle 32:
#  0 Load(0) ->  67 Load(1141) ->  45 Load(1467) ->  13 Load(2222) ->  46 Load(2513) ->  11 Load(2983) ->  0 Load(2983)
# Time of the route: 320
# Load of the route: 2983
#
# Route for vehicle 33:
#  0 Load(0) ->  26 Load(192) ->  25 Load(384) ->  39 Load(541) ->  51 Load(1175) ->  31 Load(1861) ->  30 Load(2126) ->  29 Load(2433) ->  70 Load(2983) ->  0 Load(2983)
# Time of the route: 502
# Load of the route: 2983
#
# Route for vehicle 34:
#  0 Load(0) ->  65 Load(268) ->  7 Load(711) ->  8 Load(1507) ->  64 Load(1840) ->  20 Load(2647) ->  23 Load(2992) ->  0 Load(2992)
# Time of the route: 377
# Load of the route: 2992
#
# Total time of all routes: 88.5
# Total load of all routes: 40624
